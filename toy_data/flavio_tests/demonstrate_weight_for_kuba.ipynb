# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1,1,1000)

# %%
plt.hist(x)
# Out:
# (array([100., 100., 100., 100., 100., 100., 100., 100., 100., 100.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
w = np.linspace(0,2,len(x))
plt.plot(w)

# %%
plt.hist(x)
plt.hist(x, weights=w, alpha=0.5)
# Out:
# (array([  9.90990991,  29.92992993,  49.94994995,  69.96996997,
#          89.98998999, 110.01001001, 130.03003003, 150.05005005,
#         170.07007007, 190.09009009]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)
